# %% [markdown]
# # Task 4.6 (Part Two)

# %%
# Import libraries
import pandas as pd
import numpy as np
import os
import pickle

# %%
# Import pkl files
path = r'/Users/melanie/Desktop/7:2022 Instacart Basket Analysis'

# %%
df_op_com = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_op_com
# Out:
#           Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                  0   2539329        1             1                   2
# 1                  0   2539329        1             1                   2
# 2                  0   2539329        1             1                   2
# 3                  0   2539329        1             1                   2
# 4                  0   2539329        1             1                   2
# ...              ...       ...      ...           ...                 ...
# 32434484     3421081   2977660   206209            13                   1
# 32434485     3421081   2977660   206209            13                   1
# 32434486     3421081   2977660   206209            13                   1
# 32434487     3421081   2977660   206209            13                   1
# 32434488     3421081   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_previous_order  product_id  \
# ...

# %%
# Checking shape of df_op_com
df_op_com.shape
# Out:
# (32434489, 11)

# %%
# Import products csv
df_prods = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49683       49688       49684
# 49684       49689       49685
# 49685       49690       49686
# 49686       49691       49687
# 49687       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49683          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# Checking shape of df_prods
df_prods.shape
# Out:
# (49688, 6)

# %%
# Merging df_op_com with df_prods
df_merged = pd.merge(df_prods, df_op_com, on = 'product_id')

# %%
df_merged.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id  order_number  \
# 0             19     5.8          1987   3139998      138            28
# 1             19     5.8          1989   1977647      138            30
# 2             19     5.8         11433    389851      709             2
# 3             19     5.8         12198    652770      764             1
# 4             19     5.8         12200   1813452      764             3
#
#    orders_day_of_week  order_hour_of_day  days_since_previous_order  \
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# both          32433030
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Export df_merged as pkl file
df_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_merged.pkl'))

# %%
df_merged.shape
# Out:
# (32433030, 16)
