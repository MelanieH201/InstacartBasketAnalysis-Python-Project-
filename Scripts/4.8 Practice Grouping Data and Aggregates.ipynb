# %% [markdown]
# # Task 4.8 Grouping Data and Aggregates

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Import Data
path = r'/Users/melanie/Desktop/7:2022 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_renamed.pkl'))

# %%
# Create subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 20)

# %%
df.head(10)
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
# 5           0           1  Chocolate Sandwich Cookies        61
# 6           0           1  Chocolate Sandwich Cookies        61
# 7           0           1  Chocolate Sandwich Cookies        61
# 8           0           1  Chocolate Sandwich Cookies        61
# 9           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id  order_number  orders_day_of_week  \
# 0             19     5.8   3139998      138            28                   6
# 1             19     5.8   1977647      138            30                   6
# ...

# %%
# Grouping Data
df.groupby('product_name')

# %%
# Aggregating with agg()
df.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.383626
# 2                17.253074
# 3                17.320902
# 4                17.396778
# 5                14.805859
# 6                16.424075
# 7                17.668456
# 8                15.799862
# 9                16.157130
# 10               20.993865
# 11               16.448567
# 12               15.851732
# 13               16.471454
# 14               16.625229
# 15               15.808901
# 16               17.506349
# 17               15.609994
# 18               19.536718
# 19               17.070165
# 20               16.289107
# 21               24.664122

# %%
# Grouping with same results without agg()
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.383626
# 2     17.253074
# 3     17.320902
# 4     17.396778
# 5     14.805859
# 6     16.424075
# 7     17.668456
# 8     15.799862
# 9     16.157130
# 10    20.993865
# 11    16.448567
# 12    15.851732
# 13    16.471454
# 14    16.625229
# 15    15.808901
# 16    17.506349
# 17    15.609994
# 18    19.536718
# 19    17.070165
# 20    16.289107
# 21    24.664122
# Name: order_number, dtype: float64

# %%
# Multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.383626   1  99
# 2                17.253074   1  99
# 3                17.320902   1  99
# 4                17.396778   1  99
# 5                14.805859   1  99
# 6                16.424075   1  99
# 7                17.668456   1  99
# 8                15.799862   1  98
# 9                16.157130   1  99
# 10               20.993865   1  99
# 11               16.448567   1  99
# 12               15.851732   1  99
# 13               16.471454   1  99
# 14               16.625229   1  99
# 15               15.808901   1  99
# 16               17.506349   1  99
# 17               15.609994   1  99
# 18               19.536718   1  99
# 19               17.070165   1  99
# 20               16.289107   1  99
# 21               24.664122   1  99

# %%
# Aggregating data with transform()
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(10)
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
# 5           0           1  Chocolate Sandwich Cookies        61
# 6           0           1  Chocolate Sandwich Cookies        61
# 7           0           1  Chocolate Sandwich Cookies        61
# 8           0           1  Chocolate Sandwich Cookies        61
# 9           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id  order_number  orders_day_of_week  \
# 0             19     5.8   3139998      138            28                   6
# 1             19     5.8   1977647      138            30                   6
# ...

# %%
# Deriving with loc() 
pd.options.display.max_rows = None

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    4869701
# Loyal customer      3157290
# New customer        1900001
# Name: loyalty_flag, dtype: int64
